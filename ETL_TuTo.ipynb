# %% [markdown]
# <a href="https://colab.research.google.com/github/yanos84/Tutorials/blob/main/ETL_TuTo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /content/Sources.zip
# Out:
# Archive:  /content/Sources.zip
#    creating: Sources/
#   inflating: Sources/anonym.json
#   inflating: Sources/catalog.csv

# %%
# !pip install pandas sqlalchemy psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 40.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine

csv_file = pd.read_csv("/content/Sources/catalog.csv")
json_file = pd.read_json("/content/Sources/anonym.json")

# %%
display(csv_file)
display(json_file)
# Out:
#       id        device_model oper_sys  app_usage  screen_on  battery  \
# 0      1      Google Pixel 5  Android        393        6.4     1872
# 1      2           OnePlus 9  Android        268        4.7     1331
# 2      3        Xiaomi Mi 11  Android        154        4.0      761
# 3      4      Google Pixel 5  Android        239        4.8     1676
# 4      5           iPhone 12      iOS        187        4.3     1367
# ..   ...                 ...      ...        ...        ...      ...
# 695  696           iPhone 12      iOS         92        3.9     1082
# 696  697        Xiaomi Mi 11  Android        316        6.8     1965
# 697  698      Google Pixel 5  Android         99        3.1      942
# 698  699  Samsung Galaxy S21  Android         62        1.7      431
# 699  700           OnePlus 9  Android        212        5.4     1306
#
#      app_number  data_usage
# 0            67        1122
# 1            42         944
# 2            32         322
# ...

# %%
merged_df = pd.merge(csv_file, json_file, on='id')
print("\nMerged data (first 5 rows):")
display(merged_df)
# Out:
# Merged data (first 5 rows):
#       id        device_model oper_sys  app_usage  screen_on  battery  \
# 0      1      Google Pixel 5  Android        393        6.4     1872
# 1      2           OnePlus 9  Android        268        4.7     1331
# 2      3        Xiaomi Mi 11  Android        154        4.0      761
# 3      4      Google Pixel 5  Android        239        4.8     1676
# 4      5           iPhone 12      iOS        187        4.3     1367
# ..   ...                 ...      ...        ...        ...      ...
# 695  696           iPhone 12      iOS         92        3.9     1082
# 696  697        Xiaomi Mi 11  Android        316        6.8     1965
# 697  698      Google Pixel 5  Android         99        3.1      942
# 698  699  Samsung Galaxy S21  Android         62        1.7      431
# 699  700           OnePlus 9  Android        212        5.4     1306
#
#      app_number  data_usage  age  gender  user_behav_class
# ...
